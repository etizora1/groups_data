# %% [markdown]
# ## Using the Facebook API

# %% [markdown]
# Before you can use the api you need to set up a developer account with facebook
# https://developers.facebook.com

# %% [markdown]
# https://towardsdatascience.com/how-to-use-facebook-graph-api-and-extract-data-using-python-1839e19d6999
#
# - **Getting the Access Token:**
# - To be able to extract data from Facebook using a python code you need to register as a developer on Facebook and then have an access token. Here are the steps for it.
# - Go to link developers.facebook.com, create an account there.
# - Go to link developers.facebook.com/tools/explorer.
# - Go to “My apps” drop down in the top right corner and select “add a new app”. Choose a display name and a category and then “Create App ID”.
# - Again get back to the same link developers.facebook.com/tools/explorer. You will see “Graph API Explorer” below “My Apps” in the top right corner. From “Graph API Explorer” drop down, select your app.
# - Then, select “Get Token”. From this drop down, select “Get User Access Token”. Select permissions from the menu that appears and then select “Get Access Token.”
# - Go to link developers.facebook.com/tools/accesstoken. Select “Debug” corresponding to “User Token”. Go to “Extend Token Access”. This will ensure that your token does not expire every two hours.

# %% [markdown]
# ## Imports

# %%
import urllib3
import os
import time
import facebook
from facebook import GraphAPIError
import requests
import json
import numpy as np
import pandas as pd

# %%
# User Access Token from FB developer account
token = '#####'

# %%
data = np.load('facebook_data/fb_Art.npy')

# %%
data[600]
# Out:
# [{'id': '1690025891268682',
#   'location': {'city': 'Inverness',
#    'country': 'United Kingdom',
#    'latitude': 57.462587,
#    'longitude': -4.2106326,
#    'street': '24 Tomatin Road',
#    'zip': 'IV2 4UA'},
#   'name': 'Inverness Artificial Grass'},
#  {'id': '741905332516360',
#   'location': {'city': 'Muir of Ord',
#    'country': 'United Kingdom',
#    'latitude': 57.52093,
#    'longitude': -4.46879,
#    'street': 'A832',
#    'zip': 'IV6 7'},
#   'name': 'Tore Art Gallery'},
#  {'id': '697897613697490',
#   'location': {'city': 'Inverness',
#    'country': 'United Kingdom',
#    'latitude': 57.4479038,
#    'longitude': -4.1772526,
#    'street': 'Redwood Crescent',
#    'zip': 'IV2 6HB'},
#   'name': 'K J Campbell Artist'},
#  {'id': '197602250815084',
#   'location': {'city': 'Inverness',
#    'country': 'United Kingdom',
#    'latitude': 57.483437,
#    'longitude': -4.459924,
#    'zip': 'IV4 7AE'},
#   'name': 'Kirstie Cohen Fine Art Limited'},
#  {'id': '254200694913142',
#   'location': {'city': 'Nairn, Morayshire',
#    'latitude': 57.515727,
#    'longitude': -3.973197,
#    'zip': 'IV12 5XS'},
#   'name': 'E J MacArthur'},
#  {'description': 'Ruth Black works in various textile disciplines.  She concentrates on embroidery, feltmaking and weaving, but often uses other techniques to create her work.  In addition, she teaches feltmaking and works with community groups to produce large pieces of public art.',
#   'id': '845477115501869',
#   'location': {'city': 'Inverness',
#    'country': 'United Kingdom',
#    'latitude': 57.47237,
#    'longitude': -4.38643,
#    'street': 'The Workshop, Inchmore, Kirkhill',
#    'zip': 'IV5 7PX'},
#   'name': 'Ruth Black Textile Artist'},
#  {'description': 'Handcrafted gifts, Chitchat Jar (family game), photography.',
#   'id': '1433681980041987',
#   'location': {'city': 'Muir of Ord',
#    'country': 'United Kingdom',
#    'latitude': 57.52121,
#    'longitude': -4.46002,
#    'street': 'Highfield Circle'},
#   'name': 'Solas Art Studio'},
#  {'description': "I've set up this page to show all my paintings and drawings etc that I do without clogging up the main facebook feed with them. If you are interested, great :) ",
#   'id': '1107077289424176',
#   'location': {'city': 'Inverness',
#    'country': 'United Kingdom',
#    'latitude': 57.46591,
#    'longitude': -4.2602,
#    'zip': 'IV3 8JK'},
#   'name': 'The Catnip Cattery'}]

# %% [markdown]
# ## Functions

# %%
def fb_pagefinder(activity, center, search_radius, token=token):
    lat = center[0]
    lng = center[1]
    graph = facebook.GraphAPI(access_token=token, timeout=200)
    events = graph.request(
        'search?q=events%20{}&fields=name,id,description,location&type=place&center={},{}&distance={}&limit=100'.format(
        activity, lat, lng, search_radius))
    return events


def get_nextpg(events, activity):
    all_events=[]
    counter = 0
    
    while(True):
        try:
            for event in events:
                counter += 1
                all_events.append(events['data'])
            # Attempt to make a request to the next page of data, if it exists.
            events=requests.get(events['paging']['next']).json()
            print(counter)
        except KeyError:
            # When there are no more pages (['paging']['next']), break from the
            # loop and end the script.
            break
            
    new_npy = np.load('facebook_data/fb_%s.npy'%activity) if os.path.isfile('facebook_data/fb_%s.npy'%activity) else [] #get data if exist
    np.save('facebook_data/fb_%s.npy'%activity,np.append(new_npy,all_events)) #save the new
    
    return all_events


        
def fb_main(activity, center, search_radius, token=token):
    events = fb_pagefinder(activity, center, search_radius, token=token)
    get_nextpg(events, activity)
    

    
def get_df(activity):
    message= "--(fb_%s.npy) doesn't exist--"%activity
    data= 'facebook_data/fb_%s.npy'%activity
    fb_data = np.load(data) if os.path.isfile(data) else print(message)
    
    if len(fb_data) != 0:
        try:
            fb_info =fb_data[0]['data']
        except KeyError:
            fb_info = fb_data

        grp_id,name,location,latitude,longitude=[],[],[],[],[]
        for i in fb_info:
            grp_id.append(i['id'])
            name.append(i['name'])
            location.append(i['location'])
            
        df = pd.DataFrame([grp_id,name,location]).T
        df.columns=['grp_id','name','location']
        
        return df
    
    else:
        print('--no data---')
        pass

# %% [markdown]
# ## Data

# %%
data = pd.read_csv('Loneliness group key words.csv')
data.head()
# Out:
#   Children (< 16 years) Young adults (16 - 24 years) Adults (25 - 49 years)  \
# 0                 Sport                        Sport                  Sport
# 1                   NaN                         Yoga                   Yoga
# 2                   NaN                        Bokwa                  Bokwa
# 3                   NaN                      Fitness                Fitness
# 4                   Gym                          Gym                    Gym
#
#   Older people (> 50 years) Welsh translation Polish translation
# 0                     Sport         Chwaraeon              Sport
# 1                      Yoga              Yoga               Joga
# 2                     Bokwa             Bokwa              Bokwa
# 3                   Fitness         Ffitrwydd           Zdatność
# 4                       Gym            Campfa           Siłownia

# %% [markdown]
# ### Concatenating all the different colmuns:
# * this piece of code drops all the duplicates, drops all NA values and sorts them in alphabetical order

# %%
# all Groups in the English Language
data_1 = pd.concat([data['Children (< 16 years)'],
                   data['Young adults (16 - 24 years)'],
                   data['Adults (25 - 49 years)'],
                   data['Older people (> 50 years)']
                  ]).drop_duplicates().dropna().sort_values().reset_index(drop=True)

data_2 = pd.concat([data['Welsh translation'],
                   data['Polish translation']
                  ]).drop_duplicates().dropna().sort_values().reset_index(drop=True)

# %%
data_1
# Out:
# 0                      10km
# 1                       2km
# 2                       5km
# 3                 Allotment
# 4                       Art
# 5                   Beavers
# 6                      Bike
# 7                      Bird
# 8              Body Balance
# 9                 Body Pump
# 10                    Bokwa
# 11                 Bootcamp
# 12                  Bowling
# 13                    Bowls
# 14                 Brownies
# 15                  Camera
# 16                    Chess
# 17                   Church
# 18                  College
# 19                Community
# 20    Computer Game Forums?
# 21                  Cosplay
# 22                  Cricket
# 23                  Crochet
# 24             Cross stitch
# 25                     Cubs
# 26                    Cycle
# 27                  Cycling
# 28                    Dance
# 29                  Dancing
#               ...
# 60                  Reading
# 61                   Retire
# 62                   Rotary
# 63                    Rugby
# 64                      Run
# 65                   School
# 66                   Scouts
# 67           Senior Section
# 68                   Sewing
# 69                  Singles
# 70           Slimming World
# 71                    Sport
# 72                  Support
# 73                     Swim
# 74                  Tai Chi
# 75                   Tennis
# 76         The Boys Brigade
# 77                  Theatre
# 78                  Toddler
# 79               University
# 80                 Veterans
# 81                     Walk
# 82           Weightwatchers
# 83                 Wildlife
# 84        Women's Institute
# 85                 Woodwork
# 86                  Worship
# 87                     Xbox
# 88                     Yoga
# 89                    Youth
# dtype: object

# %%
cities = np.load('main_cities.npy')
cities
# Out:
# array([[ 51.89107295,  -0.42303041],
#        [ 51.456659  ,  -0.9696512 ],
#        [ 52.0429797 ,  -0.7589607 ],
#        [ 52.5738875 ,  -0.2416701 ],
#        [ 53.4018582 ,  -2.56802236],
#        [ 50.338466  ,  -4.7882104 ],
#        [ 54.53525645,  -1.55294298],
#        [ 54.8948478 ,  -2.9362311 ],
#        [ 52.9212617 ,  -1.4761491 ],
#        [ 50.3712659 ,  -4.1425658 ],
#        [ 50.74467035,  -1.8579809 ],
#        [ 53.7435722 ,  -0.3394758 ],
#        [ 50.84522125,  -0.14975851],
#        [ 51.6020246 ,  -0.9153487 ],
#        [ 51.8653705 ,  -2.2458192 ],
#        [ 51.5073219 ,  -0.1276474 ],
#        [ 53.4791301 ,  -2.2441009 ],
#        [ 50.9025349 ,  -1.404189  ],
#        [ 52.0553813 ,  -2.7151735 ],
#        [ 51.6553875 ,  -0.3957425 ],
#        [ 50.72414995,  -1.17274588],
#        [ 51.3876562 ,   0.5457712 ],
#        [ 53.8182212 ,  -3.0564845 ],
#        [ 52.6361398 ,  -1.1330789 ],
#        [ 53.5677371 ,  -0.0736289 ],
#        [ 53.4054719 ,  -2.9805392 ],
#        [ 52.628606  ,   1.29227   ],
#        [ 53.9590555 ,  -1.0815361 ],
#        [ 52.2385239 ,  -0.902493  ],
#        [ 55.1241236 ,  -1.5018084 ],
#        [ 52.9534161 ,  -1.1492773 ],
#        [ 51.7520131 ,  -1.2578499 ],
#        [ 52.6699351 ,  -0.7284623 ],
#        [ 52.6780419 ,  -2.4514273 ],
#        [ 51.3813864 ,  -2.3596963 ],
#        [ 53.3806626 ,  -1.4702278 ],
#        [ 53.0162014 ,  -2.1812607 ],
#        [ 52.0579495 ,   1.1526345 ],
#        [ 51.2352672 ,  -0.5653624 ],
#        [ 54.9770924 ,  -1.6142059 ],
#        [ 52.5246182 ,  -1.4684488 ],
#        [ 52.4776875 ,  -1.8948516 ],
#        [ 51.1103444 ,  -0.1801094 ],
#        [ 53.7974185 ,  -1.5437941 ],
#        [ 51.5613683 ,  -1.7856853 ],
#        [ 52.1911849 ,  -2.2206585 ],
#        [ 55.856656  ,  -4.2435817 ],
#        [ 55.9496416 ,  -3.1902352 ],
#        [ 57.1482429 ,  -2.0928095 ],
#        [ 56.4605938 ,  -2.97019   ],
#        [ 55.8481954 ,  -4.4249329 ],
#        [ 55.7653249 ,  -4.182994  ],
#        [ 57.4790124 ,  -4.225739  ],
#        [ 55.8878144 ,  -3.5263401 ],
#        [ 55.9477764 ,  -3.9882568 ],
#        [ 56.0713724 ,  -3.4616183 ],
#        [ 55.4594119 ,  -4.6326702 ],
#        [ 56.3956402 ,  -3.4345334 ],
#        [ 55.6101306 ,  -4.4985359 ],
#        [ 55.947877  ,  -4.7591972 ],
#        [ 56.1181242 ,  -3.9360012 ],
#        [ 55.9991959 ,  -3.784376  ],
#        [ 55.6143018 ,  -4.6655544 ],
#        [ 55.0699746 ,  -3.6095639 ],
#        [ 55.9188378 ,  -4.3317347 ],
#        [ 55.902607  ,  -4.4039569 ],
#        [ 55.7721544 ,  -4.334073  ],
#        [ 56.5597942 ,  -2.581465  ],
#        [ 55.9421202 ,  -3.0538516 ],
#        [ 57.6487891 ,  -3.3148459 ],
#        [ 56.1156137 ,  -3.7922423 ],
#        [ 57.5068566 ,  -1.7830752 ],
#        [ 55.8751189 ,  -3.1059076 ],
#        [ 53.30835885,  -4.63014805],
#        [ 51.7863044 ,  -3.22937644],
#        [ 51.55735365,  -3.56527018],
#        [ 51.5745432 ,  -3.2208487 ],
#        [ 51.4816546 ,  -3.1791934 ],
#        [ 51.6797331 ,  -4.1620223 ],
#        [ 52.4143113 ,  -4.0816846 ],
#        [ 53.2968237 ,  -3.7258927 ],
#        [ 53.3207425 ,  -3.4907258 ],
#        [ 53.2199037 ,  -3.0661782 ],
#        [ 53.2277187 ,  -4.1268822 ],
#        [ 51.7490624 ,  -3.3786183 ],
#        [ 51.8191413 ,  -3.0140809 ],
#        [ 51.5954335 ,  -3.787263  ],
#        [ 51.5882332 ,  -2.9974967 ],
#        [ 51.7117492 ,  -5.0293161 ],
#        [ 52.5135785 ,  -3.314371  ],
#        [ 51.713353  ,  -3.445555  ],
#        [ 51.6211442 ,  -3.9467751 ],
#        [ 51.6513456 ,  -3.0276774 ],
#        [ 51.4043548 ,  -3.2690216 ],
#        [ 53.0465068 ,  -2.9938137 ]])

# %% [markdown]
# #### the waits:  facebook has a limit of 200 requests per hour hence the waits

# %%
counter = 0

for d in data_1[60:]:
    print(d)
    
    for city in cities:
        counter += 1
        time.sleep(18)
        try:
            fb_main(d,city,16093.4)
        except GraphAPIError as e:
            err1 = 'Please retry your request later'
            err2 = 'request limit reached'
            err3 = 'exceeded the rate limit'
            
            if err1 in str(e):
                print(e)
                time.sleep(600)
                continue
                
            elif err2 in str(e):
                print(e)
                time.sleep(600)
                continue
                
            elif err3 in str(e):
                print(e)
                time.sleep(3600)
                continue
            else:
                raise e
                
        print('--%s--counter--%d--'%(city,counter))
# Out:
# Computer Game Forums?
# --[ 51.89107295  -0.42303041]--counter--1--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.0429797  -0.7589607]--counter--3--
# --[ 52.5738875  -0.2416701]--counter--4--
# --[ 53.4018582   -2.56802236]--counter--5--
# --[ 50.338466   -4.7882104]--counter--6--
# --[ 54.53525645  -1.55294298]--counter--7--
# --[ 54.8948478  -2.9362311]--counter--8--
# --[ 52.9212617  -1.4761491]--counter--9--
# --[ 50.3712659  -4.1425658]--counter--10--
# --[ 50.74467035  -1.8579809 ]--counter--11--
# --[ 53.7435722  -0.3394758]--counter--12--
# --[ 50.84522125  -0.14975851]--counter--13--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.8653705  -2.2458192]--counter--15--
# --[ 51.5073219  -0.1276474]--counter--16--
# --[ 53.4791301  -2.2441009]--counter--17--
# --[ 50.9025349  -1.404189 ]--counter--18--
# --[ 52.0553813  -2.7151735]--counter--19--
# --[ 51.6553875  -0.3957425]--counter--20--
# --[ 50.72414995  -1.17274588]--counter--21--
# --[ 51.3876562   0.5457712]--counter--22--
# --[ 53.8182212  -3.0564845]--counter--23--
# --[ 52.6361398  -1.1330789]--counter--24--
# --[ 53.5677371  -0.0736289]--counter--25--
# --[ 53.4054719  -2.9805392]--counter--26--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.9590555  -1.0815361]--counter--28--
# --[ 52.2385239  -0.902493 ]--counter--29--
# --[ 55.1241236  -1.5018084]--counter--30--
# --[ 52.9534161  -1.1492773]--counter--31--
# --[ 51.7520131  -1.2578499]--counter--32--
# --[ 52.6699351  -0.7284623]--counter--33--
# --[ 52.6780419  -2.4514273]--counter--34--
# --[ 51.3813864  -2.3596963]--counter--35--
# --[ 53.3806626  -1.4702278]--counter--36--
# --[ 53.0162014  -2.1812607]--counter--37--
# --[ 52.0579495   1.1526345]--counter--38--
# --[ 51.2352672  -0.5653624]--counter--39--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.5246182  -1.4684488]--counter--41--
# --[ 52.4776875  -1.8948516]--counter--42--
# --[ 51.1103444  -0.1801094]--counter--43--
# --[ 53.7974185  -1.5437941]--counter--44--
# --[ 51.5613683  -1.7856853]--counter--45--
# --[ 52.1911849  -2.2206585]--counter--46--
# --[ 55.856656   -4.2435817]--counter--47--
# --[ 55.9496416  -3.1902352]--counter--48--
# --[ 57.1482429  -2.0928095]--counter--49--
# --[ 56.4605938  -2.97019  ]--counter--50--
# --[ 55.8481954  -4.4249329]--counter--51--
# --[ 55.7653249  -4.182994 ]--counter--52--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.8878144  -3.5263401]--counter--54--
# --[ 55.9477764  -3.9882568]--counter--55--
# --[ 56.0713724  -3.4616183]--counter--56--
# --[ 55.4594119  -4.6326702]--counter--57--
# --[ 56.3956402  -3.4345334]--counter--58--
# --[ 55.6101306  -4.4985359]--counter--59--
# --[ 55.947877   -4.7591972]--counter--60--
# --[ 56.1181242  -3.9360012]--counter--61--
# --[ 55.9991959  -3.784376 ]--counter--62--
# --[ 55.6143018  -4.6655544]--counter--63--
# --[ 55.0699746  -3.6095639]--counter--64--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.902607   -4.4039569]--counter--66--
# --[ 55.7721544  -4.334073 ]--counter--67--
# --[ 56.5597942  -2.581465 ]--counter--68--
# --[ 55.9421202  -3.0538516]--counter--69--
# --[ 57.6487891  -3.3148459]--counter--70--
# --[ 56.1156137  -3.7922423]--counter--71--
# --[ 57.5068566  -1.7830752]--counter--72--
# --[ 55.8751189  -3.1059076]--counter--73--
# --[ 53.30835885  -4.63014805]--counter--74--
# --[ 51.7863044   -3.22937644]--counter--75--
# --[ 51.55735365  -3.56527018]--counter--76--
# --[ 51.5745432  -3.2208487]--counter--77--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.6797331  -4.1620223]--counter--79--
# --[ 52.4143113  -4.0816846]--counter--80--
# --[ 53.2968237  -3.7258927]--counter--81--
# --[ 53.3207425  -3.4907258]--counter--82--
# --[ 53.2199037  -3.0661782]--counter--83--
# --[ 53.2277187  -4.1268822]--counter--84--
# --[ 51.7490624  -3.3786183]--counter--85--
# --[ 51.8191413  -3.0140809]--counter--86--
# --[ 51.5954335  -3.787263 ]--counter--87--
# --[ 51.5882332  -2.9974967]--counter--88--
# --[ 51.7117492  -5.0293161]--counter--89--
# --[ 52.5135785  -3.314371 ]--counter--90--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.6211442  -3.9467751]--counter--92--
# --[ 51.6513456  -3.0276774]--counter--93--
# --[ 51.4043548  -3.2690216]--counter--94--
# --[ 53.0465068  -2.9938137]--counter--95--
# Cosplay
# --[ 51.89107295  -0.42303041]--counter--96--
# --[ 51.456659   -0.9696512]--counter--97--
# --[ 52.0429797  -0.7589607]--counter--98--
# --[ 52.5738875  -0.2416701]--counter--99--
# --[ 53.4018582   -2.56802236]--counter--100--
# --[ 50.338466   -4.7882104]--counter--101--
# --[ 54.53525645  -1.55294298]--counter--102--
# --[ 54.8948478  -2.9362311]--counter--103--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.3712659  -4.1425658]--counter--105--
# --[ 50.74467035  -1.8579809 ]--counter--106--
# --[ 53.7435722  -0.3394758]--counter--107--
# --[ 50.84522125  -0.14975851]--counter--108--
# --[ 51.6020246  -0.9153487]--counter--109--
# --[ 51.8653705  -2.2458192]--counter--110--
# --[ 51.5073219  -0.1276474]--counter--111--
# --[ 53.4791301  -2.2441009]--counter--112--
# --[ 50.9025349  -1.404189 ]--counter--113--
# --[ 52.0553813  -2.7151735]--counter--114--
# --[ 51.6553875  -0.3957425]--counter--115--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.3876562   0.5457712]--counter--117--
# --[ 53.8182212  -3.0564845]--counter--118--
# --[ 52.6361398  -1.1330789]--counter--119--
# --[ 53.5677371  -0.0736289]--counter--120--
# --[ 53.4054719  -2.9805392]--counter--121--
# --[ 52.628606   1.29227 ]--counter--122--
# --[ 53.9590555  -1.0815361]--counter--123--
# --[ 52.2385239  -0.902493 ]--counter--124--
# --[ 55.1241236  -1.5018084]--counter--125--
# --[ 52.9534161  -1.1492773]--counter--126--
# --[ 51.7520131  -1.2578499]--counter--127--
# --[ 52.6699351  -0.7284623]--counter--128--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.3813864  -2.3596963]--counter--130--
# --[ 53.3806626  -1.4702278]--counter--131--
# --[ 53.0162014  -2.1812607]--counter--132--
# --[ 52.0579495   1.1526345]--counter--133--
# --[ 51.2352672  -0.5653624]--counter--134--
# --[ 54.9770924  -1.6142059]--counter--135--
# --[ 52.5246182  -1.4684488]--counter--136--
# --[ 52.4776875  -1.8948516]--counter--137--
# --[ 51.1103444  -0.1801094]--counter--138--
# --[ 53.7974185  -1.5437941]--counter--139--
# --[ 51.5613683  -1.7856853]--counter--140--
# --[ 52.1911849  -2.2206585]--counter--141--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.9496416  -3.1902352]--counter--143--
# --[ 57.1482429  -2.0928095]--counter--144--
# --[ 56.4605938  -2.97019  ]--counter--145--
# --[ 55.8481954  -4.4249329]--counter--146--
# --[ 55.7653249  -4.182994 ]--counter--147--
# --[ 57.4790124  -4.225739 ]--counter--148--
# --[ 55.8878144  -3.5263401]--counter--149--
# --[ 55.9477764  -3.9882568]--counter--150--
# --[ 56.0713724  -3.4616183]--counter--151--
# --[ 55.4594119  -4.6326702]--counter--152--
# --[ 56.3956402  -3.4345334]--counter--153--
# --[ 55.6101306  -4.4985359]--counter--154--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 56.1181242  -3.9360012]--counter--156--
# --[ 55.9991959  -3.784376 ]--counter--157--
# --[ 55.6143018  -4.6655544]--counter--158--
# --[ 55.0699746  -3.6095639]--counter--159--
# --[ 55.9188378  -4.3317347]--counter--160--
# --[ 55.902607   -4.4039569]--counter--161--
# --[ 55.7721544  -4.334073 ]--counter--162--
# --[ 56.5597942  -2.581465 ]--counter--163--
# --[ 55.9421202  -3.0538516]--counter--164--
# --[ 57.6487891  -3.3148459]--counter--165--
# --[ 56.1156137  -3.7922423]--counter--166--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.8751189  -3.1059076]--counter--168--
# --[ 53.30835885  -4.63014805]--counter--169--
# --[ 51.7863044   -3.22937644]--counter--170--
# --[ 51.55735365  -3.56527018]--counter--171--
# --[ 51.5745432  -3.2208487]--counter--172--
# --[ 51.4816546  -3.1791934]--counter--173--
# --[ 51.6797331  -4.1620223]--counter--174--
# --[ 52.4143113  -4.0816846]--counter--175--
# --[ 53.2968237  -3.7258927]--counter--176--
# --[ 53.3207425  -3.4907258]--counter--177--
# --[ 53.2199037  -3.0661782]--counter--178--
# --[ 53.2277187  -4.1268822]--counter--179--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.8191413  -3.0140809]--counter--181--
# --[ 51.5954335  -3.787263 ]--counter--182--
# --[ 51.5882332  -2.9974967]--counter--183--
# --[ 51.7117492  -5.0293161]--counter--184--
# --[ 52.5135785  -3.314371 ]--counter--185--
# --[ 51.713353  -3.445555]--counter--186--
# --[ 51.6211442  -3.9467751]--counter--187--
# --[ 51.6513456  -3.0276774]--counter--188--
# --[ 51.4043548  -3.2690216]--counter--189--
# --[ 53.0465068  -2.9938137]--counter--190--
# Cricket
# --[ 51.89107295  -0.42303041]--counter--191--
# --[ 51.456659   -0.9696512]--counter--192--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.5738875  -0.2416701]--counter--194--
# --[ 53.4018582   -2.56802236]--counter--195--
# --[ 50.338466   -4.7882104]--counter--196--
# --[ 54.53525645  -1.55294298]--counter--197--
# --[ 54.8948478  -2.9362311]--counter--198--
# --[ 52.9212617  -1.4761491]--counter--199--
# --[ 50.3712659  -4.1425658]--counter--200--
# --[ 50.74467035  -1.8579809 ]--counter--201--
# --[ 53.7435722  -0.3394758]--counter--202--
# --[ 50.84522125  -0.14975851]--counter--203--
# --[ 51.6020246  -0.9153487]--counter--204--
# --[ 51.8653705  -2.2458192]--counter--205--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.4791301  -2.2441009]--counter--207--
# --[ 50.9025349  -1.404189 ]--counter--208--
# --[ 52.0553813  -2.7151735]--counter--209--
# --[ 51.6553875  -0.3957425]--counter--210--
# --[ 50.72414995  -1.17274588]--counter--211--
# --[ 51.3876562   0.5457712]--counter--212--
# --[ 53.8182212  -3.0564845]--counter--213--
# --[ 52.6361398  -1.1330789]--counter--214--
# --[ 53.5677371  -0.0736289]--counter--215--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.628606   1.29227 ]--counter--217--
# --[ 53.9590555  -1.0815361]--counter--218--
# --[ 52.2385239  -0.902493 ]--counter--219--
# --[ 55.1241236  -1.5018084]--counter--220--
# --[ 52.9534161  -1.1492773]--counter--221--
# --[ 51.7520131  -1.2578499]--counter--222--
# --[ 52.6699351  -0.7284623]--counter--223--
# --[ 52.6780419  -2.4514273]--counter--224--
# --[ 51.3813864  -2.3596963]--counter--225--
# --[ 53.3806626  -1.4702278]--counter--226--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.0579495   1.1526345]--counter--228--
# --[ 51.2352672  -0.5653624]--counter--229--
# --[ 54.9770924  -1.6142059]--counter--230--
# --[ 52.5246182  -1.4684488]--counter--231--
# --[ 52.4776875  -1.8948516]--counter--232--
# --[ 51.1103444  -0.1801094]--counter--233--
# --[ 53.7974185  -1.5437941]--counter--234--
# --[ 51.5613683  -1.7856853]--counter--235--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.856656   -4.2435817]--counter--237--
# --[ 55.9496416  -3.1902352]--counter--238--
# --[ 57.1482429  -2.0928095]--counter--239--
# --[ 56.4605938  -2.97019  ]--counter--240--
# --[ 55.8481954  -4.4249329]--counter--241--
# --[ 55.7653249  -4.182994 ]--counter--242--
# --[ 57.4790124  -4.225739 ]--counter--243--
# --[ 55.8878144  -3.5263401]--counter--244--
# --[ 55.9477764  -3.9882568]--counter--245--
# --[ 56.0713724  -3.4616183]--counter--246--
# --[ 55.4594119  -4.6326702]--counter--247--
# --[ 56.3956402  -3.4345334]--counter--248--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.947877   -4.7591972]--counter--250--
# --[ 56.1181242  -3.9360012]--counter--251--
# --[ 55.9991959  -3.784376 ]--counter--252--
# --[ 55.6143018  -4.6655544]--counter--253--
# --[ 55.0699746  -3.6095639]--counter--254--
# --[ 55.9188378  -4.3317347]--counter--255--
# --[ 55.902607   -4.4039569]--counter--256--
# --[ 55.7721544  -4.334073 ]--counter--257--
# --[ 56.5597942  -2.581465 ]--counter--258--
# --[ 55.9421202  -3.0538516]--counter--259--
# --[ 57.6487891  -3.3148459]--counter--260--
# --[ 56.1156137  -3.7922423]--counter--261--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.8751189  -3.1059076]--counter--263--
# --[ 53.30835885  -4.63014805]--counter--264--
# --[ 51.7863044   -3.22937644]--counter--265--
# --[ 51.55735365  -3.56527018]--counter--266--
# --[ 51.5745432  -3.2208487]--counter--267--
# --[ 51.4816546  -3.1791934]--counter--268--
# --[ 51.6797331  -4.1620223]--counter--269--
# --[ 52.4143113  -4.0816846]--counter--270--
# --[ 53.2968237  -3.7258927]--counter--271--
# --[ 53.3207425  -3.4907258]--counter--272--
# --[ 53.2199037  -3.0661782]--counter--273--
# --[ 53.2277187  -4.1268822]--counter--274--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.8191413  -3.0140809]--counter--276--
# --[ 51.5954335  -3.787263 ]--counter--277--
# --[ 51.5882332  -2.9974967]--counter--278--
# --[ 51.7117492  -5.0293161]--counter--279--
# --[ 52.5135785  -3.314371 ]--counter--280--
# --[ 51.713353  -3.445555]--counter--281--
# --[ 51.6211442  -3.9467751]--counter--282--
# --[ 51.6513456  -3.0276774]--counter--283--
# --[ 51.4043548  -3.2690216]--counter--284--
# --[ 53.0465068  -2.9938137]--counter--285--
# Crochet
# --[ 51.89107295  -0.42303041]--counter--286--
# --[ 51.456659   -0.9696512]--counter--287--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.5738875  -0.2416701]--counter--289--
# --[ 53.4018582   -2.56802236]--counter--290--
# --[ 50.338466   -4.7882104]--counter--291--
# --[ 54.53525645  -1.55294298]--counter--292--
# --[ 54.8948478  -2.9362311]--counter--293--
# --[ 52.9212617  -1.4761491]--counter--294--
# --[ 50.3712659  -4.1425658]--counter--295--
# --[ 50.74467035  -1.8579809 ]--counter--296--
# --[ 53.7435722  -0.3394758]--counter--297--
# --[ 50.84522125  -0.14975851]--counter--298--
# --[ 51.6020246  -0.9153487]--counter--299--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.5073219  -0.1276474]--counter--301--
# --[ 53.4791301  -2.2441009]--counter--302--
# --[ 50.9025349  -1.404189 ]--counter--303--
# --[ 52.0553813  -2.7151735]--counter--304--
# --[ 51.6553875  -0.3957425]--counter--305--
# --[ 50.72414995  -1.17274588]--counter--306--
# --[ 51.3876562   0.5457712]--counter--307--
# --[ 53.8182212  -3.0564845]--counter--308--
# --[ 52.6361398  -1.1330789]--counter--309--
# --[ 53.5677371  -0.0736289]--counter--310--
# --[ 53.4054719  -2.9805392]--counter--311--
# --[ 52.628606   1.29227 ]--counter--312--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.2385239  -0.902493 ]--counter--314--
# --[ 55.1241236  -1.5018084]--counter--315--
# --[ 52.9534161  -1.1492773]--counter--316--
# --[ 51.7520131  -1.2578499]--counter--317--
# --[ 52.6699351  -0.7284623]--counter--318--
# --[ 52.6780419  -2.4514273]--counter--319--
# --[ 51.3813864  -2.3596963]--counter--320--
# --[ 53.3806626  -1.4702278]--counter--321--
# --[ 53.0162014  -2.1812607]--counter--322--
# --[ 52.0579495   1.1526345]--counter--323--
# --[ 51.2352672  -0.5653624]--counter--324--
# --[ 54.9770924  -1.6142059]--counter--325--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.4776875  -1.8948516]--counter--327--
# --[ 51.1103444  -0.1801094]--counter--328--
# --[ 53.7974185  -1.5437941]--counter--329--
# --[ 51.5613683  -1.7856853]--counter--330--
# --[ 52.1911849  -2.2206585]--counter--331--
# --[ 55.856656   -4.2435817]--counter--332--
# --[ 55.9496416  -3.1902352]--counter--333--
# --[ 57.1482429  -2.0928095]--counter--334--
# --[ 56.4605938  -2.97019  ]--counter--335--
# --[ 55.8481954  -4.4249329]--counter--336--
# --[ 55.7653249  -4.182994 ]--counter--337--
# --[ 57.4790124  -4.225739 ]--counter--338--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.9477764  -3.9882568]--counter--340--
# --[ 56.0713724  -3.4616183]--counter--341--
# --[ 55.4594119  -4.6326702]--counter--342--
# --[ 56.3956402  -3.4345334]--counter--343--
# --[ 55.6101306  -4.4985359]--counter--344--
# --[ 55.947877   -4.7591972]--counter--345--
# --[ 56.1181242  -3.9360012]--counter--346--
# --[ 55.9991959  -3.784376 ]--counter--347--
# --[ 55.6143018  -4.6655544]--counter--348--
# --[ 55.0699746  -3.6095639]--counter--349--
# --[ 55.9188378  -4.3317347]--counter--350--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.7721544  -4.334073 ]--counter--352--
# --[ 56.5597942  -2.581465 ]--counter--353--
# --[ 55.9421202  -3.0538516]--counter--354--
# --[ 57.6487891  -3.3148459]--counter--355--
# --[ 56.1156137  -3.7922423]--counter--356--
# --[ 57.5068566  -1.7830752]--counter--357--
# --[ 55.8751189  -3.1059076]--counter--358--
# --[ 53.30835885  -4.63014805]--counter--359--
# --[ 51.7863044   -3.22937644]--counter--360--
# --[ 51.55735365  -3.56527018]--counter--361--
# --[ 51.5745432  -3.2208487]--counter--362--
# --[ 51.4816546  -3.1791934]--counter--363--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.4143113  -4.0816846]--counter--365--
# --[ 53.2968237  -3.7258927]--counter--366--
# --[ 53.3207425  -3.4907258]--counter--367--
# --[ 53.2199037  -3.0661782]--counter--368--
# --[ 53.2277187  -4.1268822]--counter--369--
# --[ 51.7490624  -3.3786183]--counter--370--
# --[ 51.8191413  -3.0140809]--counter--371--
# --[ 51.5954335  -3.787263 ]--counter--372--
# --[ 51.5882332  -2.9974967]--counter--373--
# --[ 51.7117492  -5.0293161]--counter--374--
# --[ 52.5135785  -3.314371 ]--counter--375--
# --[ 51.713353  -3.445555]--counter--376--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.6513456  -3.0276774]--counter--378--
# --[ 51.4043548  -3.2690216]--counter--379--
# --[ 53.0465068  -2.9938137]--counter--380--
# Cross stitch
# --[ 51.89107295  -0.42303041]--counter--381--
# --[ 51.456659   -0.9696512]--counter--382--
# --[ 52.0429797  -0.7589607]--counter--383--
# --[ 52.5738875  -0.2416701]--counter--384--
# --[ 53.4018582   -2.56802236]--counter--385--
# --[ 50.338466   -4.7882104]--counter--386--
# --[ 54.53525645  -1.55294298]--counter--387--
# --[ 54.8948478  -2.9362311]--counter--388--
# --[ 52.9212617  -1.4761491]--counter--389--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.74467035  -1.8579809 ]--counter--391--
# --[ 53.7435722  -0.3394758]--counter--392--
# --[ 50.84522125  -0.14975851]--counter--393--
# --[ 51.6020246  -0.9153487]--counter--394--
# --[ 51.8653705  -2.2458192]--counter--395--
# --[ 51.5073219  -0.1276474]--counter--396--
# --[ 53.4791301  -2.2441009]--counter--397--
# --[ 50.9025349  -1.404189 ]--counter--398--
# --[ 52.0553813  -2.7151735]--counter--399--
# --[ 51.6553875  -0.3957425]--counter--400--
# --[ 50.72414995  -1.17274588]--counter--401--
# --[ 51.3876562   0.5457712]--counter--402--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.6361398  -1.1330789]--counter--404--
# --[ 53.5677371  -0.0736289]--counter--405--
# --[ 53.4054719  -2.9805392]--counter--406--
# --[ 52.628606   1.29227 ]--counter--407--
# --[ 53.9590555  -1.0815361]--counter--408--
# --[ 52.2385239  -0.902493 ]--counter--409--
# --[ 55.1241236  -1.5018084]--counter--410--
# --[ 52.9534161  -1.1492773]--counter--411--
# --[ 51.7520131  -1.2578499]--counter--412--
# --[ 52.6699351  -0.7284623]--counter--413--
# --[ 52.6780419  -2.4514273]--counter--414--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.3806626  -1.4702278]--counter--416--
# --[ 53.0162014  -2.1812607]--counter--417--
# --[ 52.0579495   1.1526345]--counter--418--
# --[ 51.2352672  -0.5653624]--counter--419--
# --[ 54.9770924  -1.6142059]--counter--420--
# --[ 52.5246182  -1.4684488]--counter--421--
# --[ 52.4776875  -1.8948516]--counter--422--
# --[ 51.1103444  -0.1801094]--counter--423--
# --[ 53.7974185  -1.5437941]--counter--424--
# --[ 51.5613683  -1.7856853]--counter--425--
# --[ 52.1911849  -2.2206585]--counter--426--
# --[ 55.856656   -4.2435817]--counter--427--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 57.1482429  -2.0928095]--counter--429--
# --[ 56.4605938  -2.97019  ]--counter--430--
# --[ 55.8481954  -4.4249329]--counter--431--
# --[ 55.7653249  -4.182994 ]--counter--432--
# --[ 57.4790124  -4.225739 ]--counter--433--
# --[ 55.8878144  -3.5263401]--counter--434--
# --[ 55.9477764  -3.9882568]--counter--435--
# --[ 56.0713724  -3.4616183]--counter--436--
# --[ 55.4594119  -4.6326702]--counter--437--
# --[ 56.3956402  -3.4345334]--counter--438--
# --[ 55.6101306  -4.4985359]--counter--439--
# --[ 55.947877   -4.7591972]--counter--440--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.9991959  -3.784376 ]--counter--442--
# --[ 55.6143018  -4.6655544]--counter--443--
# --[ 55.0699746  -3.6095639]--counter--444--
# --[ 55.9188378  -4.3317347]--counter--445--
# --[ 55.902607   -4.4039569]--counter--446--
# --[ 55.7721544  -4.334073 ]--counter--447--
# --[ 56.5597942  -2.581465 ]--counter--448--
# --[ 55.9421202  -3.0538516]--counter--449--
# --[ 57.6487891  -3.3148459]--counter--450--
# --[ 56.1156137  -3.7922423]--counter--451--
# --[ 57.5068566  -1.7830752]--counter--452--
# --[ 55.8751189  -3.1059076]--counter--453--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.7863044   -3.22937644]--counter--455--
# --[ 51.55735365  -3.56527018]--counter--456--
# --[ 51.5745432  -3.2208487]--counter--457--
# --[ 51.4816546  -3.1791934]--counter--458--
# --[ 51.6797331  -4.1620223]--counter--459--
# --[ 52.4143113  -4.0816846]--counter--460--
# --[ 53.2968237  -3.7258927]--counter--461--
# --[ 53.3207425  -3.4907258]--counter--462--
# --[ 53.2199037  -3.0661782]--counter--463--
# --[ 53.2277187  -4.1268822]--counter--464--
# --[ 51.7490624  -3.3786183]--counter--465--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.5954335  -3.787263 ]--counter--467--
# --[ 51.5882332  -2.9974967]--counter--468--
# --[ 51.7117492  -5.0293161]--counter--469--
# --[ 52.5135785  -3.314371 ]--counter--470--
# --[ 51.713353  -3.445555]--counter--471--
# --[ 51.6211442  -3.9467751]--counter--472--
# --[ 51.6513456  -3.0276774]--counter--473--
# --[ 51.4043548  -3.2690216]--counter--474--
# --[ 53.0465068  -2.9938137]--counter--475--
# Cubs
# --[ 51.89107295  -0.42303041]--counter--476--
# --[ 51.456659   -0.9696512]--counter--477--
# --[ 52.0429797  -0.7589607]--counter--478--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.4018582   -2.56802236]--counter--480--
# --[ 50.338466   -4.7882104]--counter--481--
# --[ 54.53525645  -1.55294298]--counter--482--
# --[ 54.8948478  -2.9362311]--counter--483--
# --[ 52.9212617  -1.4761491]--counter--484--
# --[ 50.3712659  -4.1425658]--counter--485--
# --[ 50.74467035  -1.8579809 ]--counter--486--
# --[ 53.7435722  -0.3394758]--counter--487--
# --[ 50.84522125  -0.14975851]--counter--488--
# --[ 51.6020246  -0.9153487]--counter--489--
# --[ 51.8653705  -2.2458192]--counter--490--
# --[ 51.5073219  -0.1276474]--counter--491--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.9025349  -1.404189 ]--counter--493--
# --[ 52.0553813  -2.7151735]--counter--494--
# --[ 51.6553875  -0.3957425]--counter--495--
# --[ 50.72414995  -1.17274588]--counter--496--
# --[ 51.3876562   0.5457712]--counter--497--
# --[ 53.8182212  -3.0564845]--counter--498--
# --[ 52.6361398  -1.1330789]--counter--499--
# --[ 53.5677371  -0.0736289]--counter--500--
# --[ 53.4054719  -2.9805392]--counter--501--
# --[ 52.628606   1.29227 ]--counter--502--
# --[ 53.9590555  -1.0815361]--counter--503--
# --[ 52.2385239  -0.902493 ]--counter--504--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.9534161  -1.1492773]--counter--506--
# --[ 51.7520131  -1.2578499]--counter--507--
# --[ 52.6699351  -0.7284623]--counter--508--
# --[ 52.6780419  -2.4514273]--counter--509--
# --[ 51.3813864  -2.3596963]--counter--510--
# --[ 53.3806626  -1.4702278]--counter--511--
# --[ 53.0162014  -2.1812607]--counter--512--
# --[ 52.0579495   1.1526345]--counter--513--
# --[ 51.2352672  -0.5653624]--counter--514--
# --[ 54.9770924  -1.6142059]--counter--515--
# --[ 52.5246182  -1.4684488]--counter--516--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.1103444  -0.1801094]--counter--518--
# --[ 53.7974185  -1.5437941]--counter--519--
# --[ 51.5613683  -1.7856853]--counter--520--
# --[ 52.1911849  -2.2206585]--counter--521--
# --[ 55.856656   -4.2435817]--counter--522--
# --[ 55.9496416  -3.1902352]--counter--523--
# --[ 57.1482429  -2.0928095]--counter--524--
# --[ 56.4605938  -2.97019  ]--counter--525--
# --[ 55.8481954  -4.4249329]--counter--526--
# --[ 55.7653249  -4.182994 ]--counter--527--
# --[ 57.4790124  -4.225739 ]--counter--528--
# --[ 55.8878144  -3.5263401]--counter--529--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 56.0713724  -3.4616183]--counter--531--
# --[ 55.4594119  -4.6326702]--counter--532--
# --[ 56.3956402  -3.4345334]--counter--533--
# --[ 55.6101306  -4.4985359]--counter--534--
# --[ 55.947877   -4.7591972]--counter--535--
# --[ 56.1181242  -3.9360012]--counter--536--
# --[ 55.9991959  -3.784376 ]--counter--537--
# --[ 55.6143018  -4.6655544]--counter--538--
# --[ 55.0699746  -3.6095639]--counter--539--
# --[ 55.9188378  -4.3317347]--counter--540--
# --[ 55.902607   -4.4039569]--counter--541--
# --[ 55.7721544  -4.334073 ]--counter--542--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.9421202  -3.0538516]--counter--544--
# --[ 57.6487891  -3.3148459]--counter--545--
# --[ 56.1156137  -3.7922423]--counter--546--
# --[ 57.5068566  -1.7830752]--counter--547--
# --[ 55.8751189  -3.1059076]--counter--548--
# --[ 53.30835885  -4.63014805]--counter--549--
# --[ 51.7863044   -3.22937644]--counter--550--
# --[ 51.55735365  -3.56527018]--counter--551--
# --[ 51.5745432  -3.2208487]--counter--552--
# --[ 51.4816546  -3.1791934]--counter--553--
# --[ 51.6797331  -4.1620223]--counter--554--
# --[ 52.4143113  -4.0816846]--counter--555--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.3207425  -3.4907258]--counter--557--
# --[ 53.2199037  -3.0661782]--counter--558--
# --[ 53.2277187  -4.1268822]--counter--559--
# --[ 51.7490624  -3.3786183]--counter--560--
# --[ 51.8191413  -3.0140809]--counter--561--
# --[ 51.5954335  -3.787263 ]--counter--562--
# --[ 51.5882332  -2.9974967]--counter--563--
# --[ 51.7117492  -5.0293161]--counter--564--
# --[ 52.5135785  -3.314371 ]--counter--565--
# --[ 51.713353  -3.445555]--counter--566--
# --[ 51.6211442  -3.9467751]--counter--567--
# --[ 51.6513456  -3.0276774]--counter--568--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.0465068  -2.9938137]--counter--570--
# Cycle
# --[ 51.89107295  -0.42303041]--counter--571--
# --[ 51.456659   -0.9696512]--counter--572--
# --[ 52.0429797  -0.7589607]--counter--573--
# --[ 52.5738875  -0.2416701]--counter--574--
# --[ 53.4018582   -2.56802236]--counter--575--
# --[ 50.338466   -4.7882104]--counter--576--
# --[ 54.53525645  -1.55294298]--counter--577--
# --[ 54.8948478  -2.9362311]--counter--578--
# --[ 52.9212617  -1.4761491]--counter--579--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.74467035  -1.8579809 ]--counter--581--
# --[ 53.7435722  -0.3394758]--counter--582--
# --[ 50.84522125  -0.14975851]--counter--583--
# --[ 51.6020246  -0.9153487]--counter--584--
# --[ 51.8653705  -2.2458192]--counter--585--
# --[ 51.5073219  -0.1276474]--counter--586--
# --[ 53.4791301  -2.2441009]--counter--587--
# --[ 50.9025349  -1.404189 ]--counter--588--
# --[ 52.0553813  -2.7151735]--counter--589--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.72414995  -1.17274588]--counter--591--
# --[ 51.3876562   0.5457712]--counter--592--
# --[ 53.8182212  -3.0564845]--counter--593--
# --[ 52.6361398  -1.1330789]--counter--594--
# --[ 53.5677371  -0.0736289]--counter--595--
# --[ 53.4054719  -2.9805392]--counter--596--
# --[ 52.628606   1.29227 ]--counter--597--
# --[ 53.9590555  -1.0815361]--counter--598--
# --[ 52.2385239  -0.902493 ]--counter--599--
# --[ 55.1241236  -1.5018084]--counter--600--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.7520131  -1.2578499]--counter--602--
# --[ 52.6699351  -0.7284623]--counter--603--
# --[ 52.6780419  -2.4514273]--counter--604--
# --[ 51.3813864  -2.3596963]--counter--605--
# --[ 53.3806626  -1.4702278]--counter--606--
# --[ 53.0162014  -2.1812607]--counter--607--
# --[ 52.0579495   1.1526345]--counter--608--
# --[ 51.2352672  -0.5653624]--counter--609--
# --[ 54.9770924  -1.6142059]--counter--610--
# --[ 52.5246182  -1.4684488]--counter--611--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.1103444  -0.1801094]--counter--613--
# --[ 53.7974185  -1.5437941]--counter--614--
# --[ 51.5613683  -1.7856853]--counter--615--
# --[ 52.1911849  -2.2206585]--counter--616--
# --[ 55.856656   -4.2435817]--counter--617--
# --[ 55.9496416  -3.1902352]--counter--618--
# --[ 57.1482429  -2.0928095]--counter--619--
# --[ 56.4605938  -2.97019  ]--counter--620--
# --[ 55.8481954  -4.4249329]--counter--621--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 57.4790124  -4.225739 ]--counter--623--
# --[ 55.8878144  -3.5263401]--counter--624--
# --[ 55.9477764  -3.9882568]--counter--625--
# --[ 56.0713724  -3.4616183]--counter--626--
# --[ 55.4594119  -4.6326702]--counter--627--
# --[ 56.3956402  -3.4345334]--counter--628--
# --[ 55.6101306  -4.4985359]--counter--629--
# --[ 55.947877   -4.7591972]--counter--630--
# --[ 56.1181242  -3.9360012]--counter--631--
# --[ 55.9991959  -3.784376 ]--counter--632--
# --[ 55.6143018  -4.6655544]--counter--633--
# --[ 55.0699746  -3.6095639]--counter--634--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.902607   -4.4039569]--counter--636--
# --[ 55.7721544  -4.334073 ]--counter--637--
# --[ 56.5597942  -2.581465 ]--counter--638--
# --[ 55.9421202  -3.0538516]--counter--639--
# --[ 57.6487891  -3.3148459]--counter--640--
# --[ 56.1156137  -3.7922423]--counter--641--
# --[ 57.5068566  -1.7830752]--counter--642--
# --[ 55.8751189  -3.1059076]--counter--643--
# --[ 53.30835885  -4.63014805]--counter--644--
# --[ 51.7863044   -3.22937644]--counter--645--
# --[ 51.55735365  -3.56527018]--counter--646--
# --[ 51.5745432  -3.2208487]--counter--647--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.6797331  -4.1620223]--counter--649--
# --[ 52.4143113  -4.0816846]--counter--650--
# --[ 53.2968237  -3.7258927]--counter--651--
# --[ 53.3207425  -3.4907258]--counter--652--
# --[ 53.2199037  -3.0661782]--counter--653--
# --[ 53.2277187  -4.1268822]--counter--654--
# --[ 51.7490624  -3.3786183]--counter--655--
# --[ 51.8191413  -3.0140809]--counter--656--
# --[ 51.5954335  -3.787263 ]--counter--657--
# --[ 51.5882332  -2.9974967]--counter--658--
# --[ 51.7117492  -5.0293161]--counter--659--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.713353  -3.445555]--counter--661--
# --[ 51.6211442  -3.9467751]--counter--662--
# --[ 51.6513456  -3.0276774]--counter--663--
# --[ 51.4043548  -3.2690216]--counter--664--
# --[ 53.0465068  -2.9938137]--counter--665--
# Cycling
# --[ 51.89107295  -0.42303041]--counter--666--
# --[ 51.456659   -0.9696512]--counter--667--
# --[ 52.0429797  -0.7589607]--counter--668--
# --[ 52.5738875  -0.2416701]--counter--669--
# --[ 53.4018582   -2.56802236]--counter--670--
# --[ 50.338466   -4.7882104]--counter--671--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 54.8948478  -2.9362311]--counter--673--
# --[ 52.9212617  -1.4761491]--counter--674--
# --[ 50.3712659  -4.1425658]--counter--675--
# --[ 50.74467035  -1.8579809 ]--counter--676--
# --[ 53.7435722  -0.3394758]--counter--677--
# --[ 50.84522125  -0.14975851]--counter--678--
# --[ 51.6020246  -0.9153487]--counter--679--
# --[ 51.8653705  -2.2458192]--counter--680--
# --[ 51.5073219  -0.1276474]--counter--681--
# --[ 53.4791301  -2.2441009]--counter--682--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.0553813  -2.7151735]--counter--684--
# --[ 51.6553875  -0.3957425]--counter--685--
# --[ 50.72414995  -1.17274588]--counter--686--
# --[ 51.3876562   0.5457712]--counter--687--
# --[ 53.8182212  -3.0564845]--counter--688--
# --[ 52.6361398  -1.1330789]--counter--689--
# --[ 53.5677371  -0.0736289]--counter--690--
# --[ 53.4054719  -2.9805392]--counter--691--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.9590555  -1.0815361]--counter--693--
# --[ 52.2385239  -0.902493 ]--counter--694--
# --[ 55.1241236  -1.5018084]--counter--695--
# --[ 52.9534161  -1.1492773]--counter--696--
# --[ 51.7520131  -1.2578499]--counter--697--
# --[ 52.6699351  -0.7284623]--counter--698--
# --[ 52.6780419  -2.4514273]--counter--699--
# --[ 51.3813864  -2.3596963]--counter--700--
# --[ 53.3806626  -1.4702278]--counter--701--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.0579495   1.1526345]--counter--703--
# --[ 51.2352672  -0.5653624]--counter--704--
# --[ 54.9770924  -1.6142059]--counter--705--
# --[ 52.5246182  -1.4684488]--counter--706--
# --[ 52.4776875  -1.8948516]--counter--707--
# --[ 51.1103444  -0.1801094]--counter--708--
# --[ 53.7974185  -1.5437941]--counter--709--
# --[ 51.5613683  -1.7856853]--counter--710--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.856656   -4.2435817]--counter--712--
# --[ 55.9496416  -3.1902352]--counter--713--
# --[ 57.1482429  -2.0928095]--counter--714--
# --[ 56.4605938  -2.97019  ]--counter--715--
# --[ 55.8481954  -4.4249329]--counter--716--
# --[ 55.7653249  -4.182994 ]--counter--717--
# --[ 57.4790124  -4.225739 ]--counter--718--
# --[ 55.8878144  -3.5263401]--counter--719--
# --[ 55.9477764  -3.9882568]--counter--720--
# --[ 56.0713724  -3.4616183]--counter--721--
# --[ 55.4594119  -4.6326702]--counter--722--
# --[ 56.3956402  -3.4345334]--counter--723--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.947877   -4.7591972]--counter--725--
# --[ 56.1181242  -3.9360012]--counter--726--
# --[ 55.9991959  -3.784376 ]--counter--727--
# --[ 55.6143018  -4.6655544]--counter--728--
# --[ 55.0699746  -3.6095639]--counter--729--
# --[ 55.9188378  -4.3317347]--counter--730--
# --[ 55.902607   -4.4039569]--counter--731--
# --[ 55.7721544  -4.334073 ]--counter--732--
# --[ 56.5597942  -2.581465 ]--counter--733--
# --[ 55.9421202  -3.0538516]--counter--734--
# --[ 57.6487891  -3.3148459]--counter--735--
# --[ 56.1156137  -3.7922423]--counter--736--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.8751189  -3.1059076]--counter--738--
# --[ 53.30835885  -4.63014805]--counter--739--
# --[ 51.7863044   -3.22937644]--counter--740--
# --[ 51.55735365  -3.56527018]--counter--741--
# --[ 51.5745432  -3.2208487]--counter--742--
# --[ 51.4816546  -3.1791934]--counter--743--
# --[ 51.6797331  -4.1620223]--counter--744--
# --[ 52.4143113  -4.0816846]--counter--745--
# --[ 53.2968237  -3.7258927]--counter--746--
# --[ 53.3207425  -3.4907258]--counter--747--
# --[ 53.2199037  -3.0661782]--counter--748--
# --[ 53.2277187  -4.1268822]--counter--749--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.8191413  -3.0140809]--counter--751--
# --[ 51.5954335  -3.787263 ]--counter--752--
# --[ 51.5882332  -2.9974967]--counter--753--
# --[ 51.7117492  -5.0293161]--counter--754--
# --[ 52.5135785  -3.314371 ]--counter--755--
# --[ 51.713353  -3.445555]--counter--756--
# --[ 51.6211442  -3.9467751]--counter--757--
# --[ 51.6513456  -3.0276774]--counter--758--
# --[ 51.4043548  -3.2690216]--counter--759--
# --[ 53.0465068  -2.9938137]--counter--760--
# Dance
# --[ 51.89107295  -0.42303041]--counter--761--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.0429797  -0.7589607]--counter--763--
# --[ 52.5738875  -0.2416701]--counter--764--
# --[ 53.4018582   -2.56802236]--counter--765--
# --[ 50.338466   -4.7882104]--counter--766--
# --[ 54.53525645  -1.55294298]--counter--767--
# --[ 54.8948478  -2.9362311]--counter--768--
# --[ 52.9212617  -1.4761491]--counter--769--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.74467035  -1.8579809 ]--counter--771--
# --[ 53.7435722  -0.3394758]--counter--772--
# --[ 50.84522125  -0.14975851]--counter--773--
# --[ 51.6020246  -0.9153487]--counter--774--
# --[ 51.8653705  -2.2458192]--counter--775--
# --[ 51.5073219  -0.1276474]--counter--776--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.9025349  -1.404189 ]--counter--778--
# --[ 52.0553813  -2.7151735]--counter--779--
# --[ 51.6553875  -0.3957425]--counter--780--
# --[ 50.72414995  -1.17274588]--counter--781--
# --[ 51.3876562   0.5457712]--counter--782--
# --[ 53.8182212  -3.0564845]--counter--783--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.5677371  -0.0736289]--counter--785--
# --[ 53.4054719  -2.9805392]--counter--786--
# --[ 52.628606   1.29227 ]--counter--787--
# --[ 53.9590555  -1.0815361]--counter--788--
# --[ 52.2385239  -0.902493 ]--counter--789--
# --[ 55.1241236  -1.5018084]--counter--790--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.7520131  -1.2578499]--counter--792--
# --[ 52.6699351  -0.7284623]--counter--793--
# --[ 52.6780419  -2.4514273]--counter--794--
# --[ 51.3813864  -2.3596963]--counter--795--
# --[ 53.3806626  -1.4702278]--counter--796--
# --[ 53.0162014  -2.1812607]--counter--797--
# --[ 52.0579495   1.1526345]--counter--798--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 54.9770924  -1.6142059]--counter--800--
# --[ 52.5246182  -1.4684488]--counter--801--
# --[ 52.4776875  -1.8948516]--counter--802--
# --[ 51.1103444  -0.1801094]--counter--803--
# --[ 53.7974185  -1.5437941]--counter--804--
# --[ 51.5613683  -1.7856853]--counter--805--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.856656   -4.2435817]--counter--807--
# --[ 55.9496416  -3.1902352]--counter--808--
# --[ 57.1482429  -2.0928095]--counter--809--
# --[ 56.4605938  -2.97019  ]--counter--810--
# --[ 55.8481954  -4.4249329]--counter--811--
# --[ 55.7653249  -4.182994 ]--counter--812--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.8878144  -3.5263401]--counter--814--
# --[ 55.9477764  -3.9882568]--counter--815--
# --[ 56.0713724  -3.4616183]--counter--816--
# --[ 55.4594119  -4.6326702]--counter--817--
# --[ 56.3956402  -3.4345334]--counter--818--
# --[ 55.6101306  -4.4985359]--counter--819--
# --[ 55.947877   -4.7591972]--counter--820--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.9991959  -3.784376 ]--counter--822--
# --[ 55.6143018  -4.6655544]--counter--823--
# --[ 55.0699746  -3.6095639]--counter--824--
# --[ 55.9188378  -4.3317347]--counter--825--
# --[ 55.902607   -4.4039569]--counter--826--
# --[ 55.7721544  -4.334073 ]--counter--827--
# --[ 56.5597942  -2.581465 ]--counter--828--
# --[ 55.9421202  -3.0538516]--counter--829--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 56.1156137  -3.7922423]--counter--831--
# --[ 57.5068566  -1.7830752]--counter--832--
# --[ 55.8751189  -3.1059076]--counter--833--
# --[ 53.30835885  -4.63014805]--counter--834--
# --[ 51.7863044   -3.22937644]--counter--835--
# --[ 51.55735365  -3.56527018]--counter--836--
# --[ 51.5745432  -3.2208487]--counter--837--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.6797331  -4.1620223]--counter--839--
# --[ 52.4143113  -4.0816846]--counter--840--
# --[ 53.2968237  -3.7258927]--counter--841--
# --[ 53.3207425  -3.4907258]--counter--842--
# --[ 53.2199037  -3.0661782]--counter--843--
# --[ 53.2277187  -4.1268822]--counter--844--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.8191413  -3.0140809]--counter--846--
# --[ 51.5954335  -3.787263 ]--counter--847--
# --[ 51.5882332  -2.9974967]--counter--848--
# --[ 51.7117492  -5.0293161]--counter--849--
# --[ 52.5135785  -3.314371 ]--counter--850--
# --[ 51.713353  -3.445555]--counter--851--
# --[ 51.6211442  -3.9467751]--counter--852--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.4043548  -3.2690216]--counter--854--
# --[ 53.0465068  -2.9938137]--counter--855--
# Dancing
# --[ 51.89107295  -0.42303041]--counter--856--
# --[ 51.456659   -0.9696512]--counter--857--
# --[ 52.0429797  -0.7589607]--counter--858--
# --[ 52.5738875  -0.2416701]--counter--859--
# --[ 53.4018582   -2.56802236]--counter--860--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 54.53525645  -1.55294298]--counter--862--
# --[ 54.8948478  -2.9362311]--counter--863--
# --[ 52.9212617  -1.4761491]--counter--864--
# --[ 50.3712659  -4.1425658]--counter--865--
# --[ 50.74467035  -1.8579809 ]--counter--866--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.84522125  -0.14975851]--counter--868--
# --[ 51.6020246  -0.9153487]--counter--869--
# --[ 51.8653705  -2.2458192]--counter--870--
# --[ 51.5073219  -0.1276474]--counter--871--
# --[ 53.4791301  -2.2441009]--counter--872--
# --[ 50.9025349  -1.404189 ]--counter--873--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.6553875  -0.3957425]--counter--875--
# --[ 50.72414995  -1.17274588]--counter--876--
# --[ 51.3876562   0.5457712]--counter--877--
# --[ 53.8182212  -3.0564845]--counter--878--
# --[ 52.6361398  -1.1330789]--counter--879--
# --[ 53.5677371  -0.0736289]--counter--880--
# --[ 53.4054719  -2.9805392]--counter--881--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.9590555  -1.0815361]--counter--883--
# --[ 52.2385239  -0.902493 ]--counter--884--
# --[ 55.1241236  -1.5018084]--counter--885--
# --[ 52.9534161  -1.1492773]--counter--886--
# --[ 51.7520131  -1.2578499]--counter--887--
# --[ 52.6699351  -0.7284623]--counter--888--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.3813864  -2.3596963]--counter--890--
# --[ 53.3806626  -1.4702278]--counter--891--
# --[ 53.0162014  -2.1812607]--counter--892--
# --[ 52.0579495   1.1526345]--counter--893--
# --[ 51.2352672  -0.5653624]--counter--894--
# --[ 54.9770924  -1.6142059]--counter--895--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.4776875  -1.8948516]--counter--897--
# --[ 51.1103444  -0.1801094]--counter--898--
# --[ 53.7974185  -1.5437941]--counter--899--
# --[ 51.5613683  -1.7856853]--counter--900--
# --[ 52.1911849  -2.2206585]--counter--901--
# --[ 55.856656   -4.2435817]--counter--902--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 57.1482429  -2.0928095]--counter--904--
# --[ 56.4605938  -2.97019  ]--counter--905--
# --[ 55.8481954  -4.4249329]--counter--906--
# --[ 55.7653249  -4.182994 ]--counter--907--
# --[ 57.4790124  -4.225739 ]--counter--908--
# --[ 55.8878144  -3.5263401]--counter--909--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 56.0713724  -3.4616183]--counter--911--
# --[ 55.4594119  -4.6326702]--counter--912--
# --[ 56.3956402  -3.4345334]--counter--913--
# --[ 55.6101306  -4.4985359]--counter--914--
# --[ 55.947877   -4.7591972]--counter--915--
# --[ 56.1181242  -3.9360012]--counter--916--
# --[ 55.9991959  -3.784376 ]--counter--917--
# --[ 55.6143018  -4.6655544]--counter--918--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.9188378  -4.3317347]--counter--920--
# --[ 55.902607   -4.4039569]--counter--921--
# --[ 55.7721544  -4.334073 ]--counter--922--
# --[ 56.5597942  -2.581465 ]--counter--923--
# --[ 55.9421202  -3.0538516]--counter--924--
# --[ 57.6487891  -3.3148459]--counter--925--
# --[ 56.1156137  -3.7922423]--counter--926--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.8751189  -3.1059076]--counter--928--
# --[ 53.30835885  -4.63014805]--counter--929--
# --[ 51.7863044   -3.22937644]--counter--930--
# --[ 51.55735365  -3.56527018]--counter--931--
# --[ 51.5745432  -3.2208487]--counter--932--
# --[ 51.4816546  -3.1791934]--counter--933--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.4143113  -4.0816846]--counter--935--
# --[ 53.2968237  -3.7258927]--counter--936--
# --[ 53.3207425  -3.4907258]--counter--937--
# --[ 53.2199037  -3.0661782]--counter--938--
# --[ 53.2277187  -4.1268822]--counter--939--
# --[ 51.7490624  -3.3786183]--counter--940--
# --[ 51.8191413  -3.0140809]--counter--941--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.5882332  -2.9974967]--counter--943--
# --[ 51.7117492  -5.0293161]--counter--944--
# --[ 52.5135785  -3.314371 ]--counter--945--
# --[ 51.713353  -3.445555]--counter--946--
# --[ 51.6211442  -3.9467751]--counter--947--
# --[ 51.6513456  -3.0276774]--counter--948--
# --[ 51.4043548  -3.2690216]--counter--949--
# (#613) Calls to this api have exceeded the rate limit.
# Darts
# --[ 51.89107295  -0.42303041]--counter--951--
# --[ 51.456659   -0.9696512]--counter--952--
# --[ 52.0429797  -0.7589607]--counter--953--
# --[ 52.5738875  -0.2416701]--counter--954--
# --[ 53.4018582   -2.56802236]--counter--955--
# --[ 50.338466   -4.7882104]--counter--956--
# --[ 54.53525645  -1.55294298]--counter--957--
# --[ 54.8948478  -2.9362311]--counter--958--
# --[ 52.9212617  -1.4761491]--counter--959--
# --[ 50.3712659  -4.1425658]--counter--960--
# --[ 50.74467035  -1.8579809 ]--counter--961--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.84522125  -0.14975851]--counter--963--
# --[ 51.6020246  -0.9153487]--counter--964--
# --[ 51.8653705  -2.2458192]--counter--965--
# --[ 51.5073219  -0.1276474]--counter--966--
# --[ 53.4791301  -2.2441009]--counter--967--
# --[ 50.9025349  -1.404189 ]--counter--968--
# --[ 52.0553813  -2.7151735]--counter--969--
# --[ 51.6553875  -0.3957425]--counter--970--
# --[ 50.72414995  -1.17274588]--counter--971--
# --[ 51.3876562   0.5457712]--counter--972--
# --[ 53.8182212  -3.0564845]--counter--973--
# --[ 52.6361398  -1.1330789]--counter--974--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.4054719  -2.9805392]--counter--976--
# --[ 52.628606   1.29227 ]--counter--977--
# --[ 53.9590555  -1.0815361]--counter--978--
# --[ 52.2385239  -0.902493 ]--counter--979--
# --[ 55.1241236  -1.5018084]--counter--980--
# --[ 52.9534161  -1.1492773]--counter--981--
# --[ 51.7520131  -1.2578499]--counter--982--
# --[ 52.6699351  -0.7284623]--counter--983--
# --[ 52.6780419  -2.4514273]--counter--984--
# --[ 51.3813864  -2.3596963]--counter--985--
# --[ 53.3806626  -1.4702278]--counter--986--
# --[ 53.0162014  -2.1812607]--counter--987--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.2352672  -0.5653624]--counter--989--
# --[ 54.9770924  -1.6142059]--counter--990--
# --[ 52.5246182  -1.4684488]--counter--991--
# --[ 52.4776875  -1.8948516]--counter--992--
# --[ 51.1103444  -0.1801094]--counter--993--
# --[ 53.7974185  -1.5437941]--counter--994--
# --[ 51.5613683  -1.7856853]--counter--995--
# --[ 52.1911849  -2.2206585]--counter--996--
# --[ 55.856656   -4.2435817]--counter--997--
# --[ 55.9496416  -3.1902352]--counter--998--
# --[ 57.1482429  -2.0928095]--counter--999--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.8481954  -4.4249329]--counter--1001--
# --[ 55.7653249  -4.182994 ]--counter--1002--
# --[ 57.4790124  -4.225739 ]--counter--1003--
# --[ 55.8878144  -3.5263401]--counter--1004--
# --[ 55.9477764  -3.9882568]--counter--1005--
# --[ 56.0713724  -3.4616183]--counter--1006--
# --[ 55.4594119  -4.6326702]--counter--1007--
# --[ 56.3956402  -3.4345334]--counter--1008--
# --[ 55.6101306  -4.4985359]--counter--1009--
# --[ 55.947877   -4.7591972]--counter--1010--
# --[ 56.1181242  -3.9360012]--counter--1011--
# --[ 55.9991959  -3.784376 ]--counter--1012--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.0699746  -3.6095639]--counter--1014--
# --[ 55.9188378  -4.3317347]--counter--1015--
# --[ 55.902607   -4.4039569]--counter--1016--
# --[ 55.7721544  -4.334073 ]--counter--1017--
# --[ 56.5597942  -2.581465 ]--counter--1018--
# --[ 55.9421202  -3.0538516]--counter--1019--
# --[ 57.6487891  -3.3148459]--counter--1020--
# --[ 56.1156137  -3.7922423]--counter--1021--
# --[ 57.5068566  -1.7830752]--counter--1022--
# --[ 55.8751189  -3.1059076]--counter--1023--
# --[ 53.30835885  -4.63014805]--counter--1024--
# --[ 51.7863044   -3.22937644]--counter--1025--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.5745432  -3.2208487]--counter--1027--
# --[ 51.4816546  -3.1791934]--counter--1028--
# --[ 51.6797331  -4.1620223]--counter--1029--
# --[ 52.4143113  -4.0816846]--counter--1030--
# --[ 53.2968237  -3.7258927]--counter--1031--
# --[ 53.3207425  -3.4907258]--counter--1032--
# --[ 53.2199037  -3.0661782]--counter--1033--
# --[ 53.2277187  -4.1268822]--counter--1034--
# --[ 51.7490624  -3.3786183]--counter--1035--
# --[ 51.8191413  -3.0140809]--counter--1036--
# --[ 51.5954335  -3.787263 ]--counter--1037--
# --[ 51.5882332  -2.9974967]--counter--1038--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.5135785  -3.314371 ]--counter--1040--
# --[ 51.713353  -3.445555]--counter--1041--
# --[ 51.6211442  -3.9467751]--counter--1042--
# --[ 51.6513456  -3.0276774]--counter--1043--
# --[ 51.4043548  -3.2690216]--counter--1044--
# --[ 53.0465068  -2.9938137]--counter--1045--
# Dating
# --[ 51.89107295  -0.42303041]--counter--1046--
# --[ 51.456659   -0.9696512]--counter--1047--
# --[ 52.0429797  -0.7589607]--counter--1048--
# --[ 52.5738875  -0.2416701]--counter--1049--
# --[ 53.4018582   -2.56802236]--counter--1050--
# --[ 50.338466   -4.7882104]--counter--1051--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 54.8948478  -2.9362311]--counter--1053--
# --[ 52.9212617  -1.4761491]--counter--1054--
# --[ 50.3712659  -4.1425658]--counter--1055--
# --[ 50.74467035  -1.8579809 ]--counter--1056--
# --[ 53.7435722  -0.3394758]--counter--1057--
# --[ 50.84522125  -0.14975851]--counter--1058--
# --[ 51.6020246  -0.9153487]--counter--1059--
# --[ 51.8653705  -2.2458192]--counter--1060--
# --[ 51.5073219  -0.1276474]--counter--1061--
# ...
# --[ 53.5677371  -0.0736289]--counter--2875--
# --[ 53.4054719  -2.9805392]--counter--2876--
# --[ 52.628606   1.29227 ]--counter--2877--
# --[ 53.9590555  -1.0815361]--counter--2878--
# --[ 52.2385239  -0.902493 ]--counter--2879--
# --[ 55.1241236  -1.5018084]--counter--2880--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.7520131  -1.2578499]--counter--2882--
# --[ 52.6699351  -0.7284623]--counter--2883--
# --[ 52.6780419  -2.4514273]--counter--2884--
# --[ 51.3813864  -2.3596963]--counter--2885--
# --[ 53.3806626  -1.4702278]--counter--2886--
# --[ 53.0162014  -2.1812607]--counter--2887--
# --[ 52.0579495   1.1526345]--counter--2888--
# --[ 51.2352672  -0.5653624]--counter--2889--
# --[ 54.9770924  -1.6142059]--counter--2890--
# --[ 52.5246182  -1.4684488]--counter--2891--
# --[ 52.4776875  -1.8948516]--counter--2892--
# --[ 51.1103444  -0.1801094]--counter--2893--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.5613683  -1.7856853]--counter--2895--
# --[ 52.1911849  -2.2206585]--counter--2896--
# --[ 55.856656   -4.2435817]--counter--2897--
# --[ 55.9496416  -3.1902352]--counter--2898--
# --[ 57.1482429  -2.0928095]--counter--2899--
# --[ 56.4605938  -2.97019  ]--counter--2900--
# --[ 55.8481954  -4.4249329]--counter--2901--
# --[ 55.7653249  -4.182994 ]--counter--2902--
# --[ 57.4790124  -4.225739 ]--counter--2903--
# --[ 55.8878144  -3.5263401]--counter--2904--
# --[ 55.9477764  -3.9882568]--counter--2905--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.4594119  -4.6326702]--counter--2907--
# --[ 56.3956402  -3.4345334]--counter--2908--
# --[ 55.6101306  -4.4985359]--counter--2909--
# --[ 55.947877   -4.7591972]--counter--2910--
# --[ 56.1181242  -3.9360012]--counter--2911--
# --[ 55.9991959  -3.784376 ]--counter--2912--
# --[ 55.6143018  -4.6655544]--counter--2913--
# --[ 55.0699746  -3.6095639]--counter--2914--
# --[ 55.9188378  -4.3317347]--counter--2915--
# --[ 55.902607   -4.4039569]--counter--2916--
# --[ 55.7721544  -4.334073 ]--counter--2917--
# --[ 56.5597942  -2.581465 ]--counter--2918--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 57.6487891  -3.3148459]--counter--2920--
# --[ 56.1156137  -3.7922423]--counter--2921--
# --[ 57.5068566  -1.7830752]--counter--2922--
# --[ 55.8751189  -3.1059076]--counter--2923--
# --[ 53.30835885  -4.63014805]--counter--2924--
# --[ 51.7863044   -3.22937644]--counter--2925--
# --[ 51.55735365  -3.56527018]--counter--2926--
# --[ 51.5745432  -3.2208487]--counter--2927--
# --[ 51.4816546  -3.1791934]--counter--2928--
# --[ 51.6797331  -4.1620223]--counter--2929--
# --[ 52.4143113  -4.0816846]--counter--2930--
# --[ 53.2968237  -3.7258927]--counter--2931--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.2199037  -3.0661782]--counter--2933--
# --[ 53.2277187  -4.1268822]--counter--2934--
# --[ 51.7490624  -3.3786183]--counter--2935--
# --[ 51.8191413  -3.0140809]--counter--2936--
# --[ 51.5954335  -3.787263 ]--counter--2937--
# --[ 51.5882332  -2.9974967]--counter--2938--
# --[ 51.7117492  -5.0293161]--counter--2939--
# --[ 52.5135785  -3.314371 ]--counter--2940--
# --[ 51.713353  -3.445555]--counter--2941--
# --[ 51.6211442  -3.9467751]--counter--2942--
# --[ 51.6513456  -3.0276774]--counter--2943--
# --[ 51.4043548  -3.2690216]--counter--2944--
# (#613) Calls to this api have exceeded the rate limit.
# Nintendo
# --[ 51.89107295  -0.42303041]--counter--2946--
# --[ 51.456659   -0.9696512]--counter--2947--
# --[ 52.0429797  -0.7589607]--counter--2948--
# --[ 52.5738875  -0.2416701]--counter--2949--
# --[ 53.4018582   -2.56802236]--counter--2950--
# --[ 50.338466   -4.7882104]--counter--2951--
# --[ 54.53525645  -1.55294298]--counter--2952--
# --[ 54.8948478  -2.9362311]--counter--2953--
# --[ 52.9212617  -1.4761491]--counter--2954--
# --[ 50.3712659  -4.1425658]--counter--2955--
# --[ 50.74467035  -1.8579809 ]--counter--2956--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 50.84522125  -0.14975851]--counter--2958--
# --[ 51.6020246  -0.9153487]--counter--2959--
# --[ 51.8653705  -2.2458192]--counter--2960--
# --[ 51.5073219  -0.1276474]--counter--2961--
# --[ 53.4791301  -2.2441009]--counter--2962--
# --[ 50.9025349  -1.404189 ]--counter--2963--
# --[ 52.0553813  -2.7151735]--counter--2964--
# --[ 51.6553875  -0.3957425]--counter--2965--
# --[ 50.72414995  -1.17274588]--counter--2966--
# --[ 51.3876562   0.5457712]--counter--2967--
# --[ 53.8182212  -3.0564845]--counter--2968--
# --[ 52.6361398  -1.1330789]--counter--2969--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.4054719  -2.9805392]--counter--2971--
# --[ 52.628606   1.29227 ]--counter--2972--
# --[ 53.9590555  -1.0815361]--counter--2973--
# --[ 52.2385239  -0.902493 ]--counter--2974--
# --[ 55.1241236  -1.5018084]--counter--2975--
# --[ 52.9534161  -1.1492773]--counter--2976--
# --[ 51.7520131  -1.2578499]--counter--2977--
# --[ 52.6699351  -0.7284623]--counter--2978--
# --[ 52.6780419  -2.4514273]--counter--2979--
# --[ 51.3813864  -2.3596963]--counter--2980--
# --[ 53.3806626  -1.4702278]--counter--2981--
# --[ 53.0162014  -2.1812607]--counter--2982--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.2352672  -0.5653624]--counter--2984--
# --[ 54.9770924  -1.6142059]--counter--2985--
# --[ 52.5246182  -1.4684488]--counter--2986--
# --[ 52.4776875  -1.8948516]--counter--2987--
# --[ 51.1103444  -0.1801094]--counter--2988--
# --[ 53.7974185  -1.5437941]--counter--2989--
# --[ 51.5613683  -1.7856853]--counter--2990--
# --[ 52.1911849  -2.2206585]--counter--2991--
# --[ 55.856656   -4.2435817]--counter--2992--
# --[ 55.9496416  -3.1902352]--counter--2993--
# --[ 57.1482429  -2.0928095]--counter--2994--
# --[ 56.4605938  -2.97019  ]--counter--2995--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.7653249  -4.182994 ]--counter--2997--
# --[ 57.4790124  -4.225739 ]--counter--2998--
# --[ 55.8878144  -3.5263401]--counter--2999--
# --[ 55.9477764  -3.9882568]--counter--3000--
# --[ 56.0713724  -3.4616183]--counter--3001--
# --[ 55.4594119  -4.6326702]--counter--3002--
# --[ 56.3956402  -3.4345334]--counter--3003--
# --[ 55.6101306  -4.4985359]--counter--3004--
# --[ 55.947877   -4.7591972]--counter--3005--
# --[ 56.1181242  -3.9360012]--counter--3006--
# --[ 55.9991959  -3.784376 ]--counter--3007--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 55.0699746  -3.6095639]--counter--3009--
# --[ 55.9188378  -4.3317347]--counter--3010--
# --[ 55.902607   -4.4039569]--counter--3011--
# --[ 55.7721544  -4.334073 ]--counter--3012--
# --[ 56.5597942  -2.581465 ]--counter--3013--
# --[ 55.9421202  -3.0538516]--counter--3014--
# --[ 57.6487891  -3.3148459]--counter--3015--
# --[ 56.1156137  -3.7922423]--counter--3016--
# --[ 57.5068566  -1.7830752]--counter--3017--
# --[ 55.8751189  -3.1059076]--counter--3018--
# --[ 53.30835885  -4.63014805]--counter--3019--
# --[ 51.7863044   -3.22937644]--counter--3020--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.5745432  -3.2208487]--counter--3022--
# --[ 51.4816546  -3.1791934]--counter--3023--
# --[ 51.6797331  -4.1620223]--counter--3024--
# --[ 52.4143113  -4.0816846]--counter--3025--
# --[ 53.2968237  -3.7258927]--counter--3026--
# --[ 53.3207425  -3.4907258]--counter--3027--
# --[ 53.2199037  -3.0661782]--counter--3028--
# --[ 53.2277187  -4.1268822]--counter--3029--
# --[ 51.7490624  -3.3786183]--counter--3030--
# --[ 51.8191413  -3.0140809]--counter--3031--
# --[ 51.5954335  -3.787263 ]--counter--3032--
# --[ 51.5882332  -2.9974967]--counter--3033--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.5135785  -3.314371 ]--counter--3035--
# --[ 51.713353  -3.445555]--counter--3036--
# --[ 51.6211442  -3.9467751]--counter--3037--
# --[ 51.6513456  -3.0276774]--counter--3038--
# --[ 51.4043548  -3.2690216]--counter--3039--
# --[ 53.0465068  -2.9938137]--counter--3040--
# Parent
# --[ 51.89107295  -0.42303041]--counter--3041--
# --[ 51.456659   -0.9696512]--counter--3042--
# --[ 52.0429797  -0.7589607]--counter--3043--
# --[ 52.5738875  -0.2416701]--counter--3044--
# --[ 53.4018582   -2.56802236]--counter--3045--
# --[ 50.338466   -4.7882104]--counter--3046--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 54.8948478  -2.9362311]--counter--3048--
# --[ 52.9212617  -1.4761491]--counter--3049--
# --[ 50.3712659  -4.1425658]--counter--3050--
# --[ 50.74467035  -1.8579809 ]--counter--3051--
# --[ 53.7435722  -0.3394758]--counter--3052--
# --[ 50.84522125  -0.14975851]--counter--3053--
# --[ 51.6020246  -0.9153487]--counter--3054--
# --[ 51.8653705  -2.2458192]--counter--3055--
# --[ 51.5073219  -0.1276474]--counter--3056--
# --[ 53.4791301  -2.2441009]--counter--3057--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.0553813  -2.7151735]--counter--3059--
# --[ 51.6553875  -0.3957425]--counter--3060--
# --[ 50.72414995  -1.17274588]--counter--3061--
# --[ 51.3876562   0.5457712]--counter--3062--
# --[ 53.8182212  -3.0564845]--counter--3063--
# --[ 52.6361398  -1.1330789]--counter--3064--
# --[ 53.5677371  -0.0736289]--counter--3065--
# --[ 53.4054719  -2.9805392]--counter--3066--
# --[ 52.628606   1.29227 ]--counter--3067--
# --[ 53.9590555  -1.0815361]--counter--3068--
# --[ 52.2385239  -0.902493 ]--counter--3069--
# --[ 55.1241236  -1.5018084]--counter--3070--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.7520131  -1.2578499]--counter--3072--
# --[ 52.6699351  -0.7284623]--counter--3073--
# --[ 52.6780419  -2.4514273]--counter--3074--
# --[ 51.3813864  -2.3596963]--counter--3075--
# --[ 53.3806626  -1.4702278]--counter--3076--
# --[ 53.0162014  -2.1812607]--counter--3077--
# --[ 52.0579495   1.1526345]--counter--3078--
# --[ 51.2352672  -0.5653624]--counter--3079--
# --[ 54.9770924  -1.6142059]--counter--3080--
# --[ 52.5246182  -1.4684488]--counter--3081--
# --[ 52.4776875  -1.8948516]--counter--3082--
# --[ 51.1103444  -0.1801094]--counter--3083--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.5613683  -1.7856853]--counter--3085--
# --[ 52.1911849  -2.2206585]--counter--3086--
# --[ 55.856656   -4.2435817]--counter--3087--
# --[ 55.9496416  -3.1902352]--counter--3088--
# --[ 57.1482429  -2.0928095]--counter--3089--
# --[ 56.4605938  -2.97019  ]--counter--3090--
# --[ 55.8481954  -4.4249329]--counter--3091--
# --[ 55.7653249  -4.182994 ]--counter--3092--
# --[ 57.4790124  -4.225739 ]--counter--3093--
# --[ 55.8878144  -3.5263401]--counter--3094--
# --[ 55.9477764  -3.9882568]--counter--3095--
# --[ 56.0713724  -3.4616183]--counter--3096--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 56.3956402  -3.4345334]--counter--3098--
# --[ 55.6101306  -4.4985359]--counter--3099--
# --[ 55.947877   -4.7591972]--counter--3100--
# --[ 56.1181242  -3.9360012]--counter--3101--
# --[ 55.9991959  -3.784376 ]--counter--3102--
# --[ 55.6143018  -4.6655544]--counter--3103--
# --[ 55.0699746  -3.6095639]--counter--3104--
# --[ 55.9188378  -4.3317347]--counter--3105--
# --[ 55.902607   -4.4039569]--counter--3106--
# --[ 55.7721544  -4.334073 ]--counter--3107--
# --[ 56.5597942  -2.581465 ]--counter--3108--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 57.6487891  -3.3148459]--counter--3110--
# --[ 56.1156137  -3.7922423]--counter--3111--
# --[ 57.5068566  -1.7830752]--counter--3112--
# --[ 55.8751189  -3.1059076]--counter--3113--
# --[ 53.30835885  -4.63014805]--counter--3114--
# --[ 51.7863044   -3.22937644]--counter--3115--
# --[ 51.55735365  -3.56527018]--counter--3116--
# --[ 51.5745432  -3.2208487]--counter--3117--
# --[ 51.4816546  -3.1791934]--counter--3118--
# --[ 51.6797331  -4.1620223]--counter--3119--
# --[ 52.4143113  -4.0816846]--counter--3120--
# --[ 53.2968237  -3.7258927]--counter--3121--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.2199037  -3.0661782]--counter--3123--
# --[ 53.2277187  -4.1268822]--counter--3124--
# --[ 51.7490624  -3.3786183]--counter--3125--
# --[ 51.8191413  -3.0140809]--counter--3126--
# --[ 51.5954335  -3.787263 ]--counter--3127--
# --[ 51.5882332  -2.9974967]--counter--3128--
# --[ 51.7117492  -5.0293161]--counter--3129--
# --[ 52.5135785  -3.314371 ]--counter--3130--
# --[ 51.713353  -3.445555]--counter--3131--
# --[ 51.6211442  -3.9467751]--counter--3132--
# --[ 51.6513456  -3.0276774]--counter--3133--
# --[ 51.4043548  -3.2690216]--counter--3134--
# (#613) Calls to this api have exceeded the rate limit.
# Photography
# --[ 51.89107295  -0.42303041]--counter--3136--
# --[ 51.456659   -0.9696512]--counter--3137--
# --[ 52.0429797  -0.7589607]--counter--3138--
# --[ 52.5738875  -0.2416701]--counter--3139--
# --[ 53.4018582   -2.56802236]--counter--3140--
# --[ 50.338466   -4.7882104]--counter--3141--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 54.8948478  -2.9362311]--counter--3143--
# --[ 52.9212617  -1.4761491]--counter--3144--
# --[ 50.3712659  -4.1425658]--counter--3145--
# --[ 50.74467035  -1.8579809 ]--counter--3146--
# --[ 53.7435722  -0.3394758]--counter--3147--
# --[ 50.84522125  -0.14975851]--counter--3148--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.8653705  -2.2458192]--counter--3150--
# --[ 51.5073219  -0.1276474]--counter--3151--
# --[ 53.4791301  -2.2441009]--counter--3152--
# --[ 50.9025349  -1.404189 ]--counter--3153--
# --[ 52.0553813  -2.7151735]--counter--3154--
# --[ 51.6553875  -0.3957425]--counter--3155--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.3876562   0.5457712]--counter--3157--
# --[ 53.8182212  -3.0564845]--counter--3158--
# --[ 52.6361398  -1.1330789]--counter--3159--
# --[ 53.5677371  -0.0736289]--counter--3160--
# --[ 53.4054719  -2.9805392]--counter--3161--
# --[ 52.628606   1.29227 ]--counter--3162--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 52.2385239  -0.902493 ]--counter--3164--
# --[ 55.1241236  -1.5018084]--counter--3165--
# --[ 52.9534161  -1.1492773]--counter--3166--
# --[ 51.7520131  -1.2578499]--counter--3167--
# --[ 52.6699351  -0.7284623]--counter--3168--
# --[ 52.6780419  -2.4514273]--counter--3169--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 53.3806626  -1.4702278]--counter--3171--
# --[ 53.0162014  -2.1812607]--counter--3172--
# --[ 52.0579495   1.1526345]--counter--3173--
# --[ 51.2352672  -0.5653624]--counter--3174--
# --[ 54.9770924  -1.6142059]--counter--3175--
# --[ 52.5246182  -1.4684488]--counter--3176--
# (#613) Calls to this api have exceeded the rate limit.
# --[ 51.1103444  -0.1801094]--counter--3178--
# --[ 53.7974185  -1.5437941]--counter--3179--
# --[ 51.5613683  -1.7856853]--counter--3180--
# --[ 52.1911849  -2.2206585]--counter--3181--
# --[ 55.856656   -4.2435817]--counter--3182--
# --[ 55.9496416  -3.1902352]--counter--3183--
# (#613) Calls to this api have exceeded the rate limit.
# (#613) Calls to this api have exceeded the rate limit.
# ---------------------------------------------------------------------------
# GraphAPIError                             Traceback (most recent call last)
# <ipython-input-14-6c2e1dc73e06> in <module>()
#       9         try:
# ---> 10             fb_main(d,city,16093.4)
#      11         except GraphAPIError as e:
#
# <ipython-input-3-721d21c6ee06> in fb_main(activity, center, search_radius, token)
#      56 def fb_main(activity, center, search_radius, token=token):
# ---> 57     o = fb_pagefinder(activity, center, search_radius, token=token)
#      58     fb_data = pagination(o, activity)
#
# <ipython-input-3-721d21c6ee06> in fb_pagefinder(activity, center, search_radius, token)
#       7         'search?q=events%20{}&fields=name,id,description,location&type=place&center={},{}&distance={}&limit=100'.format(
# ----> 8         activity, lat, lng, search_radius))
#       9 #     except GraphAPIError:
#
# /home/onsbigdata/anaconda3/lib/python3.6/site-packages/facebook/__init__.py in request(self, path, args, post_args, files, method)
#     271         if result and isinstance(result, dict) and result.get("error"):
# --> 272             raise GraphAPIError(result)
#     273         return result
#
# GraphAPIError: (#613) Calls to this api have exceeded the rate limit.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-6c2e1dc73e06> in <module>()
#      26             elif err3 in str(e):
#      27                 print(e)
# ---> 28                 time.sleep(1800)
#      29                 continue
#      30             else:
#
# KeyboardInterrupt:
